# %% [markdown]
# This notebook:
#
# 1. Installs required packages (Colab).
# 2. Sets global configuration for deterministic runs.
# 3. Prepares the directory paths used in later notebooks.
# 4. Verifies GPU availability.

# %%
# !pip install -q transformers datasets evaluate accelerate peft pandas matplotlib scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.7 MB/s eta 0:00:00

# %%
import os
import torch
import random
import numpy as np

# deterministic seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# root paths
PROJECT_ROOT = "/content/thesis-peft-llm"
os.makedirs(PROJECT_ROOT, exist_ok=True)

SUBDIRS = [
    "configs",
    "src",
    "notebooks",
    "outputs/models",
    "outputs/logs",
    "outputs/kd_logits",
    "outputs/results",
]

for sd in SUBDIRS:
    os.makedirs(os.path.join(PROJECT_ROOT, sd), exist_ok=True)

PROJECT_ROOT
# Out:
# '/content/thesis-peft-llm'

# %%
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Tesla T4

# %% [markdown]
# Proceed to Notebook 01 (Teacher BERT-large Fine-Tuning) once this notebook is executed and the environment is confirmed working.
